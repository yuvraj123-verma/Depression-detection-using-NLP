# %%
# Importing essential libraries
import numpy as np
import pickle
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
# Loading the dataset
df = pd.read_csv('./data/tweets_combined.csv')
print(df.shape)
# Out:
# (1686, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0        2432          2432
# 1        1069          1069
# 2        1357          1357
# 3        1727          1727
# 4        1950          1950
#
#                                                tweet  target
# 0  Avoid facial cleansers containing harsh chemic...       0
# 1  146    ???????????????????????????????????????...       0
# 2  You let me drown in my own tears which held ev...       0
# 3  Don't ever frown upon someone chasing a dream....       0
# 4  bro why is everyone so  and blacked out? i was...       0

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
# Cleaning the reviews
corpus = []

# Create an object of PorterStemmer
ps = PorterStemmer()

for i in range(0, df.shape[0]):
    # Cleaning special character from the reviews
    review = re.sub(pattern='[^a-zA-Z]', repl=' ', string=df['tweet'][i])

    # convert entire review into lower case
    review = review.lower()

    # Tokenizing the review by words
    review_words = review.split()

    # Removing stopword then do stemming
    review_words = [lemmatizer.lemmatize(word) for word in review_words if word not in set(stopwords.words('english'))]

    # Joining the stemmed words
    review = ' '.join(review_words)

    # Creating a corpus
    corpus.append(review)
    
corpus
# Out:
# ['avoid facial cleanser containing harsh chemical irritate weaken protective barrier skin use natural cleanser',
#  '',
#  'let drown tear held everything hated regretted loved could',
#  'ever frown upon someone chasing dream remember chasing one humility',
#  'bro everyone blacked gone hour hell broke loose',
#  'little miss debbie downer',
#  'drink numb pain away easier way way control',
#  'timhortons please please please make jalape jack sandwich regular looove',
#  'snorkel time fury key west',
#  'mrosenbaum happy birthday awesome filled day awesomeness',
#  'living downtown first time tiff happening schedule today excitement thechildrenact stanleytucci emmathompson',
#  'wen u post one time pic twitter com l r v',
#  'feel ever painful stigma prevents honesty problem let keep difficult conversation going x pic twitter com dwxfpvi ix',
#  'gloomy day outside like',
#  'perseveres good luck mercury award darling anohnitweets pic twitter com imvghq',
#  'woke neighbor singing perfect ed sheeran mood set',
#  'damn flamin n ni thought funny',
#  'one right way live life kind genuine honest open love amp laugh often mindfulness healingmb',
#  'pic twitter com v hspluyft',
#  'playing july pm special',
#  'want help give office call learn may treatment waiting',
#  'known going go sunny yesterday cloudy today still done anything differently',
#  'try hard forget person loved pic twitter com szlsq msnq',
#  'anybody wanna switch place go back hawaii tomorrow',
#  'lost seat house senate vote people clearly rejecting notion',
#  'bui bui ah boi dressed acting like uncle eye glued phone screen sitting first free seat',
#  'laying bed listening christmas music',
#  'loose hope ourself people demotivate u',
#  'hold every moment calm raging sea walk fire heal disease',
#  'real happiness come person truly love',
#  'people often also',
#  'halloweentown fave halloween movie',
#  'appreciate day paid vacation job still want return feel like quitting',
#  'beyond entertained case sad thing witness watch loving dm flattered cantdoitlikeme poorthing',
#  'ageing population risk depression myriad health effect higher healthcare cost well rising childcare cost approach like intergenerational care seem beautifully cost efficient solve problem another problem pic twitter com qoubtsrhr',
#  'dictionary word joy gladness cheerfulness exultation rapture pleasure delight',
#  'robert look like lesbian',
#  'dobrelucas always make smile',
#  'reading watching fault star space week best idea',
#  'miss much',
#  'really enjoying candle incense around house moment brings sense calm candle incense',
#  'david brook sandwich tweet much needed comic relief hilarious sopressatta',
#  'magicpencil whip cake batter cooky amp throw bakewell frangipani made almond',
#  'garyclarkjr seriously best turn blue ever seen amazing',
#  'thinking supposed yes feel',
#  'bible reading today show u lord done great thing u amp glad mouth filled laughter amp tongue singing',
#  'happy new year everyone best',
#  'caused low serotonin serotonin motivates hence depressed people motivation activity creates serotonin',
#  'name',
#  'littlest brother leaving tonight like hour left happy moving',
#  'huueducation thanks happy sabbs hope talk lunch',
#  'casting potential learning swim photography project pic twitter com rnjp ux ev',
#  'oh canada sung like terrible mlbtheshow',
#  'chikagaiheichou carla took eren bench could sit sensing weariness thought would best',
#  'stuck around long gained follow today im gonna',
#  'need strong false hope weak hope',
#  'cry eye right',
#  'hello everyone morning sun rising dominicanrepublic hope great day today keep',
#  'actually every goddamn song album strongest sadest beautiful song ever',
#  'w pic twitter com q vtlykgym',
#  'annarxbs lolitsluan oh lord love heart feel good happy make possible xx',
#  'least minute ago effect twitter torture still lingers inside',
#  'marathoning chuck netflix finally finished depressed damn',
#  'heard person detailing branded cloth arrogantly today sounded like wearing instead cloth',
#  'harmful may think pic twitter com n l kdyz',
#  'ole miss game depressing watch',
#  'mcmalveiro hi miguel awesome thank much updating u claire',
#  'mindfulness therapy application depression healing emotional pain powerful approach learned',
#  'killingthetown always awesome shanehelmscom make tremendous',
#  'u get oreo shake burger king',
#  'ground control captain tom eclipse mind blowing solareclipse',
#  'wxladyfelicia wptv fox wflx cityofboynton horrible picture cause make jealous',
#  'good morning start every morning waking thinking thing grateful goodmorning',
#  'strapless wedding dress look awful people njulianne hough looked great',
#  'person plan better life people wanna live',
#  'said people never cross serious',
#  'done enough today time',
#  '',
#  'ddlovato rowing mile across atlantic ocean fight get rt please',
#  'entrepreneur real blessing flexibility love one charge great blessed',
#  'playing total dance',
#  'tu haces reir make laugh laugh friend jaja haha',
#  'watching sister keeper late best idea',
#  'love smile',
#  'happier long time n happy smile beingme wifey',
#  'shreyaghoshal waiting fv live session excited happy bdw sings lot song u session',
#  'vica strange amazing love picture',
#  'wait dont think scarf actually teaser',
#  'glad way eastenders lee storyline',
#  'came home parent taking christmas decoration',
#  'depression may carry feeling worthlessness feel like anything make feel worse drag even deeper state push back set small daily accomplish sure pic twitter com vhc libpw',
#  'anybody want talk im',
#  'today already great start',
#  'justinoearlwood awesome news blue',
#  'eluded u matter tomorrow run faster stretch arm farther',
#  'lady singing really loudly headphone making everyone giggle greateranglia train journey smile',
#  'anything help gun law background check enough problem n country alleviate unnecessary suffering n country continue experience consequence hurt ppl hurt ppl love support prevents heals',
#  'one night edinburgh would perfect',
#  'nj spread cheer colleague otherwise dull life like hey dude u got chill email',
#  'danabente well thank sincerely',
#  'good news ten week friday pretty good day carefree',
#  'add snapchat dm snapcode amosc snapchat sc snap',
#  'heard willy nelson singing scientist thought original discovered covering coldplay',
#  'itsjordansroom good morning well miss jordan cheerful day',
#  'watch revenge movie write journal let',
#  'deni amp known friendship goal adorable mutuals nu tweet three time day depression',
#  '',
#  'youre youre living past youre youre living future youre youre living present',
#  'coachforward respect breed cooperation whereas fear breed doubt well said',
#  'fabulous evening mayflower theatre watching play go wrong u stitch evening veryfunny laughter',
#  'never stay silent let anyone intimidate silence let make world better safer place kid wallofsilence',
#  'going bigapple tomorrow loving njtransit commute wearing khaki whiteshirt maybeblue brownshoes macys joy jealousyet n usa',
#  'face great depression pic twitter com duwwvhckyp',
#  'stephenasmith made laugh today told caller turn volume marvingaye thing levity',
#  'blessed wonderful older sister happy',
#  'u mean ur u start pissing blood u complete permission depressed count ur blessing',
#  'anohnitweets lp much',
#  'get see amazing beautiful adopted mom new year eve see christmas either',
#  'ww w',
#  'away follower whisky whiskyfun smile humour giggle',
#  'god antidote never leave u',
#  'hate twitter anyone today pic twitter com q kkho mcr',
#  'st thomas tweet watch pll wifi suck',
#  'happiness product effort make someone else happy gretta brooker palmer',
#  'complete christmas withdrawl',
#  'far lonely person go pic twitter com gbdkxgzodh',
#  'combat make bed le inclined get back stay day',
#  'smile great investment collect better feel nice smiling day goodmorning',
#  'fact leaving warm weather palm tree negative weather snow literally could make cry',
#  'kohge buddhism verse cleanse oneself incense buddha',
#  'week painfree',
#  'beautiful day start cheerful letting joy lord spring lt n nnelly cruz',
#  'futhiemasina lol nah u subscrib r pm n pay r day thus anada r pm lol stream n use de app using ur data smile',
#  'zayuuum bey tatas got huge lol yummy',
#  'make happy make smile laugh much breathe love long live f f',
#  'reach goal hide drawer keep front face time wednesdaywisdom',
#  '',
#  'dro everything',
#  'optimism success achieve outlook positive thinking excuse failure',
#  'maybe chaebol future wang',
#  'pic twitter com ujzyacftj',
#  'lost bet nephew lucas wearing rest day pic twitter com h ltmo',
#  'best thing australianninjawarrior tonight watching failed attempt bomb slider hilarious laughingsohard',
#  'really excited see team year especially moving next year guy start playing significant minute',
#  'barely tweet follower',
#  'great meeting great friend superstar lawyer bryan freedman ftllp amazing person much many',
#  'thesocialctv never leave couch excited weary',
#  'happy birthday ryanrolison awesome day keeping cape great',
#  'feeling get drawing tablet pro expert manga drawer right bat',
#  'go back time st grade walk shove bully playground little asshole n stupidreasonstousetimetravel',
#  'aegyotaetae oyeakasha one favourite clip',
#  'jaden lindner acquire deadly scowl like going pretty happy old',
#  'need wave little curl',
#  'ww w',
#  'fucked car sleep',
#  'happy birthday shanteriai miss ton excited back florida hear turkey date',
#  'mst k punt bunny bunny punt love laughing whoisstevesmith',
#  'anxiety heart man cause depression good word make glad proverb',
#  'mi stress spanish town shopping centre celebrating yr mi memba dem groundbreaking',
#  'martinpincot haha martinpincot sent sext vicar holy holy twist bad n n fun joy laughter n',
#  'sometimes wonder tom selleck ever think remember tom selleck absolutely idea',
#  'pine apple let call pineapple funny',
#  'willlanno man u r bitter manu making great stride',
#  'cteeezy lmfao look sober say backwards lol date yesterday',
#  'regpcb like world love island drarms worst thing got worry',
#  'dear emma honor communicate directly kindly give tremendous opportunity chat via whats app thx',
#  'stay offline today likely theo hesitate anytime',
#  'people make laugh little louder smile little brighter life little better',
#  'start rehearsal rsc open stage macbeth next sunday good get mood',
#  'year old cousin stopped sharing location',
#  'airport run even going holiday',
#  'staying late mommy home',
#  'suppress moment anger may prevent many day sorrow chinese proverb n n makingmegaturkeywithmclisse',
#  'let u become weary good proper time reap harvest give ngalatians niv',
#  'bcolonx leave came dr',
#  'stuck situation wanna get rid way closed trapped',
#  'monty read list great people lost year',
#  'even tipsy love joe pic twitter com qhsaqdjn j',
#  'deepest darkest depth winter look holiday photo last summer',
#  'wednesday chandlerbmusic kickstarter begin ready chandlerbaymusic chandlerbayep tantrum',
#  'w ww',
#  'rrakoto took second fly mozambique awesomeness',
#  'always tear measure pain sometimes smile fake',
#  'beach today beautiful beach beautiful sand sea great like jelly fish though messageinabottle',
#  'happy birthday primo dance blessed one g',
#  'worrying empty tomorrow trouble empty today strength',
#  'god know set u free much wisdom much grief increaseth knowledge increaseth sorrow',
#  'think abt across generation time turkey sandwich mince pie company stranger seldom effective',
#  'take funky town hanover park terminus',
#  'christmas last longer',
#  'really trying look tweet watch video alison first red rock show',
#  'suffering',
#  'finished last episode new girl supposed',
#  'clearly appreciate sub harmonic one',
#  'spending last day bed rough hell sun shining',
#  'queenjlouise mamaw gereck awe thanks',
#  'make burst laughter bcs',
#  'curry really play tonight rest warrior got',
#  'pm laying bed eating chocolate santa',
#  'august album year question without doubt pic twitter com xvpqpqqvxw',
#  'much together dying loneliness albert schweitzer',
#  'nathan happy blissful birthday',
#  'traviswall strange fruit wow story america brilliant soyouthinkyoucandance',
#  'relation connection somewhere sometimes everywhere always emerson',
#  'nowadays people feeling lonelier quality friendship relationship perceived lower quality past',
#  'everyone starting go back school',
#  'deserve world feel like nobody care want love care want let people tell worth worth everything',
#  'go super saiyan',
#  'hello everyone sinong excited na live show hahaha worry',
#  'wish people understood mental illness',
#  'one chooses illness choice',
#  'rus kent isabeloakeshott inexplicably well paid talking head lecture impenetrable consultu speak dire',
#  'going keep banging co true focus get stop telling tell happy strong confident powerful co co brilliant mind listens tell pic twitter com gbqn yejsj',
#  'bath swimming like dolphin hot water left fml',
#  'seems lonely future waiting giver said wife forbidden talk job pic twitter com rcjgudss k',
#  'trying promote video youtuber k simply pointless',
#  'tryna talk somone got confused huhhhhhhhh life boring hell',
#  'frown meh',
#  'edgy depressed teenager blacked pfp pic twitter com bsqbwkkqzp',
#  'keep losing self respect u keep giving chance',
#  'really love thefosterstv really great start season resist',
#  'completely sick way hospital instead christmas party',
#  'people twitter depressing',
#  'yaaaaaaaaaaaas scotty sinclair wonderful magical',
#  'youngster need speak family wrong pic twitter com nusc rpli',
#  'walmarttoday hitting spot commercial love one town coming eat bringing chair brilliant',
#  'keep relentless eye goal perseverance joyful dedication unwavering focus get amyleighmercree',
#  'pop see elderly relative friend neighbour help combat pic twitter com zy cxtris',
#  'mind free aspect fear pain amp talk produce positive thought n affirmation thought focus nplease retweet',
#  'disorder deeper darker persistent unipolar disorder depression',
#  'hate new year',
#  'afford hate people kind time bobross tuesdaymotivation sober xa',
#  'loneliness probably one worst feeling community high priority u christian poverty want client know alone side',
#  'insecure withhold praise another achievement',
#  'living someone manic depressed life stop',
#  'chanyeol always cheering clap loudly happy talk something funny',
#  'actuallynph realjameswoods realize acting actually guy smh hercules ghostsofmississippi',
#  'rosiehale bro dissapointed il let read next time tho',
#  'miss much wait back home',
#  'problem season last year year',
#  'gotta best today keep happiness let anything bring big day today stoked',
#  'seeing school idol fill energy make want cheer make also want sing dance together',
#  'rt talkspace cost company billion year absenteeism reduced productivity result million lost work day year',
#  'amazonprimeday basically new favorite holiday gps watch food storage pet toy book acquired amazon happy shopping',
#  'weekend end bow hunting season',
#  'get image mind everywhere busy like money around like change status quo',
#  'put movie u watch family one everyone left bed hope ur',
#  '',
#  'h ever tweeted tweet like etc etc people like tooo show sadness social medium strong',
#  'really need know composer wrote bubble know blame week long melancholy',
#  'chad sarah honestly ex year ago cbb horrifying',
#  'ruined whole sunday',
#  'worst kind pain keeping laughing avoid tear falling',
#  'morning good vibe today people july goodmorning twitter happy',
#  'fine really mean pic twitter com agotjdgzh',
#  'cancelled chewing gum devastated',
#  'serious let treat seriously brush tell someone one tell react',
#  'commsruss luheron sooooo needed call adorable needyaunty pupster',
#  'craving ce fiore remembered gone forever',
#  'take le muscle laugh frown stop facial amp mental aging laugh strongly amp often lead effectively leadership',
#  'murmuring complaining psyche start thinking say thanks alive',
#  'believe day already back work tomorrow',
#  'oh love love love glee billy joel number',
#  'new bit alarming',
#  'course raj twisted tea bag graduate never got throw boston tea party',
#  'ever got paid impractical joker one people tell guy would heartbeat hilarious',
#  'daily liveswe must see happiness make u grateful grateful make u happy',
#  'think dream motivate u fear paralyze u chris hogan dream fear life',
#  'cry baby since missus tucked bed earplug problem',
#  'might trying fill void heart sort thing place belongs jesus christ music worry love smm',
#  'tayylittle mmm way start day yummy',
#  'harden heart provocation day temptation wilderness psalm kjv',
#  'skinnytaste made chicken tikka masala w cauliflower amp pea tonight delicious even get chance snap pic delicious',
#  'go try part life end feeling like le part started pic twitter com j nxrwdb',
#  'christinasnp great news must hurting folk happy',
#  'music empowering nit literally bring people tear smile laughter many emotion',
#  'day improve landscape game make pause menu ability save load',
#  'best week w ppl wish another goodbye',
#  'every girl deserves guy make smile',
#  'even turn holiday',
#  'talk roller coaster season',
#  'got striked awesomeness blinding people glory nosleep',
#  'give happiness show self',
#  'gunnergale miss gale really really appreciate follow back one biggest fan',
#  'got work food house bc leaving tomorrow mcdonald even open right',
#  'wednesday chandlerbmusic kickstarter begin ready chandlerbaymusic chandlerbayep tantrum',
#  'w ww ww w pic twitter com c ncrt puf',
#  'think post gay weekend blue bought dildo',
#  'nail polish hardened gummy place bottle pan boiling water polish like new',
#  'winter holiday challenging season older adult especially living alone come epl september pm learn way deal special guest cris hughes aarp pic twitter com rh fhim',
#  'clinically ft dec pic twitter com oopadoai',
#  'successful moment start toward laudable goal jbenson success quoteoftheday happiness',
#  'one night want get truck drive think',
#  'reminder office closed tomorrow thursday january see new year',
#  'aint flinch tho give lol',
#  'sometimes understand kurt cobain blew head',
#  'feeling unwanted terrible mother teresa',
#  'jk realize taehyung taehyung revenge would love',
#  'drowning homework assignment still say yes friend call',
#  'ally twitter',
#  'day lord hath made rejoice amp glad',
#  'miracle j yaaay finally brave enought comment vlive',
#  'finally famous football team uae usual bad luck go see',
#  'heal must make friend emotion creates right condition healing occur please rt',
#  'w pic twitter com rdzmwejxlz',
#  'omg commanding staff soon sensing situation country estimated billion',
#  'user unable think clearly retain learned probably quite may suffer period',
#  'smile could never make frown',
#  'laying bed think life think death neither one appeal',
#  'take smoke detector month stop beeping wondering lazy lol funny comedy laugh crackmeup hilarious',
#  'today died mech fortnite going black profile picture smh head',
#  'male elf lord ring better hair',
#  'hit m lopez gonna teacher anymore',
#  'last red zone sunday long time',
#  'dread going work early morning always come back home happy amp smiling goodday',
#  'uk loss louisville make heart hurt',
#  'three shift start next part tutorship response enjoyingthelastfewdays excited nervous newchallanges',
#  'arrived wait read learn specialneedsandlegalentitlement nd edition good st edition',
#  'snow boise ak',
#  'say u become corrupt deep sense america',
#  'felt laughing hard sleep remember',
#  'scratched inch ice car go sledging done enough snow stayed home pic twitter com rarhnljlmt',
#  'good afternoon uk chart u chart could take note u',
#  'one changed radio station office still christmas music',
#  'watch bobsburgersfox lunch anymore laughing way much acceptable crazylady',
#  'thing people help become happy explain cid death prevented',
#  'mom talk suicide people selfish go funeral shuts door',
#  'see smiling steam coffee cup',
#  'last something honest noble utterly despairing somehow full hope',
#  'officer hero dog instagram adorable doglovers',
#  'idol julius murdered senator',
#  'want read book learn book damn expensive reading pdf format computer screen suck',
#  'plum blossom patterned white ceramic smoking pipe',
#  'author copy landed australia agent soon able hold one flick excitement stonecircle',
#  'hope everyone safe fantastic day',
#  'joy come stop choosing circumstance make miserable take courage create joyful life',
#  'add snapchat dfdf n dick pussy nude horny anal as bigbooty bob cock blowjob sex sexy snap nany horny girl',
#  'man laugh silly family amp friend enough life laughter goofiness silly',
#  'kb krishnabeura twitter twitterindia verified congrats krishna sir',
#  'always grow toenail shave duh',
#  'serious conversation regarding institutional racism black black crime better understood',
#  'abctv ausenate annabelcrabb confess watch last week bad going episode accessibility',
#  'honesty bravery wonderful trait trait great human great human triumph',
#  'right back work soon',
#  'finished whole jar nutella past hour',
#  'group open every wednesday pm pm zion centre zy call u info',
#  'bleak melody beat beautiful voice gloomy verse today world brilliant one best',
#  'burning desire must love goal thinkandgrowrich health money happiness love',
#  'yep feel right pic twitter com bafudqfbey',
#  'difficult road often lead beautiful destination keepgoing keeppushing startsomewhere key start',
#  'afraid ncause ate eat nbecause eat squared meal day joke meme dankmemes funny',
#  'poverty without hope money thing require money pic twitter com rldrbbhpv',
#  'tried goodmanbakery st time gf yr amp best baked good ever df bonus yummy',
#  '',
#  'anohni underrated album year',
#  'gammarus steel con scott helme people know serious brother awesome',
#  'hammered af watched bengal lose',
#  'another great talent lost u song stay u forever odd last christmas playing everywhere yr',
#  'want hot snapping nadd rchar n nude snapsex snapchat sexting cam hot trade pic swap horny chaud pussy',
#  'harmful may think pic twitter com lbhoutajtk',
#  'rewatching rkellys trapped closet series classic hilarious',
#  'originalmalik k youfamousenough anthonymuraco gg bro lost cool',
#  'w pic twitter com zeq qhgy u',
#  'nikkiwoods start use smile confidence',
#  'happy weather',
#  'morning watched hummingbird two cardinal bunch finch large bunny baby bunny feasting backyard happy',
#  'pointless statement brain would make non depressed brain would probably never come matter bad life ultimately life look pointless alive please grab onto life hold',
#  'say rogerfederer awestruck',
#  'next story depression also awesome super lady shine tough time tell story help others',
#  'noodle tea nyummmmmmy n yum yummy ddlg abdl chgl noodle',
#  'finally finished one tree hill know life',
#  'hate tan line refuse tan salon anymore',
#  'even trail mix pretzel left',
#  'game officially assume loss bylsma lehner',
#  'happy birthday day trip great day super nice weather blue sky good mood fun love ice cream lycklig f delsedag land',
#  'heart every human sense cannot put expect close allah',
#  'girl want load dm horny cum snap dmme cumtribute cocktribute',
#  '',
#  'arrifaun great way start day lmao',
#  'mgbarbieri spalktalk saw linkedin comment sent thanks message',
#  'good morning start wheel free course pune',
#  'itsjohnjosh yes glad',
#  'sea',
#  'alarm bel oc limburg unknown address',
#  'gonna die fucking final',
#  'loved pic twitter com iv owhaj q',
#  'text mom something wrong answer',
#  'well good thing cut anymore tho',
#  'w ww w w',
#  'u r u r living n past u r anxious u r living n future u r peace u r living n present lao tzu',
#  'helen bywater sdworxuki tonynjo congratulation jo fantastic year inspiring',
#  'called slut last night um one sex every guy meet get right people',
#  'joegibbsracing designed scheme interstate car whoever approves approve yuck',
#  'shaftesbury lrc genius love poster excitement next monday',
#  '',
#  'ldn muscle bright early session morning work fullbody ldnmladies surprised actually helped reduce doms',
#  'need book holiday asap pic twitter com grbeuv aix',
#  'talkfreelyalway westbrookdanni haha nice know take time find much flattered',
#  'last group new project even relevant time year laid welcoming festive food pic twitter com aowwxtdona',
#  'feeling important pic twitter com posqshqcna',
#  'got ride witness amanda coker break year old bicycling world record awesome athlete amandacoker tdf relentless',
#  'strongly believe everyone met yet',
#  'made day thankyou much',
#  'also finally caved viewed year fb made feel thanks facebook',
#  'word simply amazing people twist make say anything',
#  'hopeless zone privileged american level progressing pic twitter com tphsjpcddf',
#  'time get dread back miss dread head girlswithdreads',
#  'happy birthday girly hope amazing day kkarlidawson',
#  'lisacim acaciaevans best picture ever seen beautiful happy',
#  'say rogerfederer awestruck',
#  'happy th birthday neopet retro nhappy th birthday harrison ford legendary nhappy th birthday krispy kreme delicious',
#  'jo caulfield great gif joyful',
#  'nlightjules happy birthday mamon',
#  'casper wyoming witness totality amazing eclipse',
#  'excellent customer service ao morning thank kharis help customerservice',
#  'love gg cheering eo apink rv mamamoo jjang',
#  'well seeing way shitty yr shitty night bed feel ill still miserable',
#  'past success failure indicator future performance afraid take risk',
#  'rachcolours smiling',
#  'na gamers got friend',
#  'judge people',
#  'brain tiring dream maybe vivid',
#  'finished park rec twice',
#  'sheikhsafina gut go sunk face sand',
#  'fear lisajnc god discouraged god strengthens help time',
#  'took longer expected lol hella fun though good learning experience got question hesitate ask',
#  'best photo describes pic twitter com hzngzzlxu',
#  'impressed karanka middlesbrough course stick martinez decides leave becoming',
#  'seen lord ring movie nothing look forward',
#  'chick even talk look flattered',
#  'infact keenly observe religion hater community hater currently depression attack',
#  'know existed sheer utter joy contentment experiencing grateful',
#  'time last year plane new york',
#  'last play raider till august',
#  'difficulty meant rouse discourage human spirit grow strong conflict william ellery channing',
#  'timmy said changed depressed eboy',
#  'went see big short',
#  'big dog understand',
#  'impression last hour insightful pleasure enlightening today hope service usa',
#  'welcome new follower gibbonwa halmarun cleanfaceskin mostly talking happiness amp ethicalfashion happy connect',
#  'fan nation need tougher gun law',
#  'bit funny although everything nsometimes better stranger n sing',
#  'thankxxx god mids b ed final b ahead starting new year exam',
#  'start lpn program october blessed',
#  'wake early workout fitness room smell awful come back room core',
#  'chichupedathaa rofl',
#  'mind may offer soul furnish hope intuitive answer solution eleesha',
#  'amazes many useful video youtube everyone sharing knowledge amp making money wonderful',
#  'nathansykes happy tuesday hope amazing day proud amp blessed know make world better',
#  'possibly worst min commentary sat consolation mile drive home',
#  'song repeat day pic twitter com b lmpvgypz',
#  'u get dr note excuse u work b c u go work anyway fake',
#  'ever get excited trying sleep amp even close eye like really need catnap excitement',
#  'sad depression get help get clear',
#  'quite glad spot rain happy held lunch daughter could enjoy circus antic school',
#  'temp dropped sky dark n bird went crazy pdx enjoyed solareclipse amazing',
#  'angieavlianos hey angie please see local dealer happy assist',
#  'oh right writing',
#  'loneliness frazzle body mind soul sound muted outside sound silence deafening',
#  'benmorris happy birthday big man',
#  'mike j lord welcome',
#  'work keep giving alcohol pic twitter com riydwinnkn',
#  'arcadegirl actually really like hearing thought either way hesitate share',
#  'ever fall asleep set alarm lord wake time anyways wonthedoit',
#  'anteharper always preferred quiver',
#  'thing selfie sunday reminds tomorrow monday',
#  'senfeinstein senatordurbin senfranken gop donor like hobbylobby prosecuted fbi dir known materialsupport',
#  'stop listening album beautiful pic twitter com nokz e hlp',
#  'crimemma congratulation becoming senior lecturer well deserved',
#  'people one',
#  'cannot let comcast bully indiedev paying faster lane indie devs fund ea',
#  'nothing like good leg workout start day',
#  'cream tea ntcolbygarden delicious',
#  'find really interesting show differently men v woman depression men usually manifest men workaholism addiction woman usually see classic symptom like cry mood difficulty getting bed etc pic twitter com c hi mokkb',
#  'ww w w ww',
#  'asked girl would react best friend invite birthday party one said hit real one know',
#  'u know asking friend',
#  'damn one get jb ticket',
#  'anohnitweets album simply stand',
#  'biggest challenge time year many time make older people feel old',
#  'nobetterfeelingthan teetering right edge n n joy pleasure happiness bliss anticipation',
#  'spntentation thank first solo run excited andnervous',
#  'oliver oh regretting',
#  'thank realdonaldtrump using afghanistan policy pretty smart n np look directly sun bad',
#  'new movie real hoot',
#  'oklahoma south carolina idaho louisiana see fall excitement',
#  'certain medication known cause mood significant number patient',
#  'mum got rlly bad car crash completely injured found rlly sentimental piece jewellery thought lost blessed',
#  'joy light allow monday shenanigan take away hello tuesday greet smile',
#  'genuinely perfectly happy',
#  'good see richie porte smiling feeling positive hospital bed sbstdf tonight get well soon',
#  'sanga wardene probably way converse sound funny suppress giggle',
#  'may find center peace soul joy heart understanding mind blessing amp prayer',
#  'struggled figure lightning work struck laughing lol',
#  'drunk singing along bmth asking alexandria mouse men rip parent eardrum',
#  'living downtown first time tiff happening schedule today excitement thechildrenact stanleytucci emmathompson',
#  'non profit organization offer help talk',
#  'believe day work back tomorrow',
#  'learned wizard oz metaphor monetary system wake great depression yellow brick gold oz ounce etc way',
#  'worst part life taking christmas decoration',
#  'lidl ireland wonderful experience trim star joileta made shopping wonderful experience helpful',
#  'would someone write movie like fault star',
#  'ghibiiyoongi happy birthday love hope best day glad met',
#  'heart stopping take breath away fun like lot justsayin laughing',
#  'hello fellow gamers tell nazi',
#  'matter knowledgeable experienced woman becomes always inexperienced male moron support',
#  'first class day amp hottest professor god good',
#  'may god grant u ability see unfailing love fill earth psalm awe',
#  'wrong always available right decide focus success',
#  'missing san francisco bit sister helping bit make forget',
#  'new year eve night dread dislike particularly moment',
#  'algorithm guide management next suicidal patient see ed cover complicated critical chief complaint pic twitter com z ekgdkzy',
#  'humble sight lord died christ offended dead person cannot feel anything right',
#  'johntassparker well time think concern bright shiny price tag match',
#  'hopelessness enemy prevails persists bryan stevenson',
#  'tonight episode gameofthrones epic went many emotion watching dragonwhitewalker flippinheck brilliant',
#  'funny gifs needed please dark blue day wondering got kid dead',
#  'buffettsongs life spicy bar b q hill looking good look fine soveryfine wow',
#  'feeling like deserve going love problem given whole heart person person betrayed make feel like nothing dm free reading today pic twitter com ddcsytxjbl',
#  'goodbye crappy howdy welcome equally crappy',
#  'graysondolan happy tuesday gray excited',
#  'dean fujioka history maker spotify well breaking benjamin dear agony amazing wonderful iloveyouspotify noonecaresbutido',
#  'feeling lost thought help available call u talk',
#  'first step beating take responsibility stop blaming others circumstance',
#  'people may problem concentrating remembering detail making decision may contemplate attempt commit suicide',
#  'really start word essay revision',
#  'mutuals hesitate kit fisto lightsaber',
#  'tonight feel le like christmas eve',
#  'nephew told cookie',
#  'cut lip eat spicy food b c burn',
#  'keep many secret head gonna explode noh hey notice u reading see good morning n goodmorningword',
#  'kerrykatona stunner cute like mum',
#  'depressing thing book end especially satisfactory way',
#  'know yesterday yes today im usual happy fatigued',
#  'world see movement hand clock bukowski pic twitter com smpkhu twn',
#  'many thing look forward positive lifeisgood',
#  'kdramasssss ofcourse pll bigbang theory grey anatomy grim game throne',
#  'myouimina u r idk extent u go teasing u love much',
#  'watch anohni',
#  'feel like rooting da bear',
#  'bushaiba nalhussaini happy birthday ayate',
#  'honestly considering grabbing cider putting forest gump good ugly cry',
#  'perhaps introvert according text dont hesitate friend anyone esp open minded one',
#  'welcoming first full calendar year since overcoming year go way realm uncharted',
#  'bright early class today miss nane nother one',
#  'please comment tweeter look chart adorable snap',
#  'right cross road despair calm jesus christ know get get back life empty life purposeful meaningful abundant eternal life',
#  'compact metal leaf grinder four layer pic twitter com vtan pbt h',
#  'base power definite power loneliness company create',
#  'early kicking as taking name offense',
#  'want know laughing solemn occasion always laughing v',
#  'topic famous people apparently stuff need put place mental illness non famous people',
#  'little yoga happy day noeishappy yogagirl yogaeverydamnday namaste grateful blessed',
#  '',
#  'mood caused infectious disease nutritional deficiency neurological condition physiological problem',
#  'utter loneliness writer try explain inexplicable john steinbeck',
#  'want help give office call learn may treatment waiting',
#  'im getting drunk mont blanc watching big bang theory eating cake',
#  'come jan like u stop depression kmt pic twitter com ejrynyhn',
#  'way harris teeter see white duck way back see dead duck white feather everywhere',
#  'promilasingh thank much promila aunty',
#  'still wondering syfy theme song pic twitter com e li gwifu',
#  'heal pic twitter com l qpwabvzo',
#  'news lot treating condition contact u learn',
#  'basically death show entire parole system farce pic twitter com sbtcky ixo',
#  'coachbru lol awesome moment amp also shared blogger friend mine',
#  'stevecontenyc lovely',
#  'violent men anohni',
#  'feel direct message would love interact guy',
#  'wont watching veronica mar anymore wasnt enough lost lilly duncan mother ya gotta strip everything there got something uplifting show make wanna keep watching maker veronice mar screwed bad',
#  'wajir county becoming fucked crib since august nightmare economical shutdown blackout tribalism inter clan clash impunity staged managed africa cinema influx non local many problem',
#  'let season sorrow turn lifetime bitterness fearfullymade gracefullysaved',
#  'watching jamesacaster clip bed actual legend never fails put good mood comedy legend love laughter bedtime x',
#  'wednesday chandlerbmusic kickstarter begin ready chandlerbaymusic chandlerbayep tantrum',
#  'beyond scratch ben nuttall guildfordlib official pi jam kit arrived raspberrypi excitement',
#  'new instagram another lost girl watching ellen cuz make happy pic twitter com rii zustnt',
#  'seriously increase risk developing also dying heart disease',
#  'w',
#  'wanted smash burger crutch drive',
#  'first time quite think even seen enough movie make kshock top film year',
#  'nasal spray ketamine introduced end year administration safer however pricey im iv ketamine remain treatment resistant',
#  'doesnt like meeeeeeeeeee',
#  'time year people loneliest give lonely person call sm let know care',
#  'year old son look go new year eve party stuck must mean getting old',
#  'today love life moved happy excited',
#  'good nite',
#  'realized last time someone type donating blood',
#  'dansgaming yes love making coffee drink home super',
#  'happy birthday bb hope u amazing birthday ultsdonghan',
#  'zelo right keep laughing always smile nnow wat heck deleted woke',
#  'ur best plenty good enough anyone anything meant u let ppl circumstance kill',
#  'shanemalwa majorpoonia devyanidilli believe ur mekka n madina also dikling u kiss dark dirty one',
#  'immobilization isolation self blame feeling overwhelmed finding responsiveness one context characterize',
#  'absolutely blown away batthemusical evening incredible set slick choreography holy moly insaaane vocal awe',
#  'news lot treating condition contact u learn',
#  'moto x play showed software update security update mb',
#  'year ago ft air en route australia via dubai pic twitter com fafckwtnj',
#  'noooo jim missed next season',
#  'feel like guy chan like hamilton',
#  'summer drawing close incredible build life dream kindness hard work amp imagination manifest music',
#  'bear stolen sofa pic twitter com goi pz',
#  'holy moley dreaded moment extrovert alone first time holiday',
#  'glorify rationalize pic twitter com kcwhsijer',
#  'nothing better going holiday weather grim home',
#  'extra lazy today',
#  'spreecoza wish spree could stock shoe bigger size range always miss promotion',
#  'mom puerto rican lively colorful',
#  'horny snapchat jchrisco horny nude trade dm snap girl fun bored like follo follo follow retweeet likeforfolow',
#  'shahidafridi best great watch u go big sir tremendous hit ndts boom boom afridi',
#  'tarabrazil guess got ghd need dread coming getting ready mine boot straighter',
#  'know hard live waste life help always available seek',
#  'believe burrito left sink nobody though trash',
#  'aacobe bibby time lol',
#  'gachas deresute enstars',
#  'w ww w w',
#  'got place school start monday excited even day haha',
#  'titsjpeg yeah funny sexy',
#  'hate sister say going kill ugh fucking triggering',
#  'really give notre dame chance game',
#  'love find pic pic love hurt',
#  'muqryyy happy birthday machaaaa stay awesome murah rezeki selalu',
#  'christmas mean love actually',
#  'vibe local texas roadhouse',
#  'carrerae would introduce show one season brooklyn nine nine come back',
#  'nice stay small city time time starrynight',
#  'spending majority day bed relaxing amp catching hollyoaks relax',
#  'happy new year got much next month overpowering guess start try work towards happy',
#  'god help israel isaiah u today afraid discouraged ur god strengthen help amp hold u',
#  'love outside right sunrise sunset sky bright blue brings peace',
#  'officially done grey anatomy',
#  'upset able pay ticket really want see lion king',
#  'mcgregor clown hilarious mayweathervsmcgregor',
#  'see smiling past like thinking nfind rest oh soul sea storm still know name n jesus n ilovejesus',
#  'believing key attaining want life start believing',
#  'selfish love necessary pic twitter com cemc sqc',
#  'many different symptom pic twitter com ceorrkfncl',
#  'christmas without pic twitter com ikzghx zi',
#  'since red china entered wto u factory closed trump',
#  'nail polish hardened gummy place bottle pan boiling water polish like new',
#  'whitey dinner called ahead shake burger seasonedcurlyfries havetoeatfast',
#  'matter much zescounitedfc light forest end getting lost n zescoforest n ssbola',
#  'three big tub ben jerry mum gave sister',
#  'bugsyseigal reading twitter lunchtime angry',
#  'need hope today ask god heart take devil cast away kenneth copeland',
#  'enjoyment seeing thing ex happen karma whatgoesaroundcomesaround',
#  'laughter creates positive aura amp transforms beautiful dynamic amp attractive person n yoga yogalaugh',
#  'jeannepaulshop crocbead pleasing color palette',
#  'irrespective level someone sympathizing definitely help rest',
#  'katsekhotho lemii loco falter katli',
#  'three blunts left',
#  'finished game throne last night gonna life april',
#  'holiday tough struggling holiday want talk',
#  'follow famous chick snap put snapping back amp next snap say dude stop sending peepees cute',
#  'good morning family took time wish mom happy birthday thank love blessed',
#  'trump want make america great guest asks obama kenyan born half brother help',
#  'living fall called cure peddler twitter seek professional medical help',
#  'news lot treating condition contact u learn',
#  'cuttimecomic adorable need',
#  'bethanblog happy help anything please hesitate ask thanks james k',
#  'tragic day lad pic twitter com qvhvgfnjfz',
#  'huedrinkwater happy birthday cuzy xxx',
#  'spend day creating smile today',
#  'ever fall asleep set alarm lord wake time anyways wonthedoit',
#  'chiropractor time crackle pop chiropractor',
#  'heat sufficient reason jump people get hurt cycle pain happens',
#  'dropping son morning shopping girl shoe wedding fun afternoon tl explode today',
#  'separate earth anohni',
#  'dad big day le week away excited',
#  'mine baby headache love smile frown wrong right pain happiness everything',
#  'ww line line pic twitter com rldg ogynz',
#  'ot still exist julid deletesoon',
#  'doesnt like meeeeeeeeeee',
#  'yesterday lost day worth streak different people',
#  'sorry happiness came rather unexpectedly ill try keep tweet',
#  'nexxhelmets revit thank guy pleasure honor work tea wine expedition',
#  'raven brown min go looking good texan',
#  'getting unexpected phone call instantly cheer amp make smile week itsthelittlethings smile',
#  'starting positive thing exercise writing good thing happened help surviving bad day',
#  'maxinewaters love relentless thank voice country',
#  'low brain serotonin level range emotion available sufferer major depressive disorder pic twitter com hjjybmdhax',
#  'diet whole family order pizza',
#  'really need commission work',
#  'well thoroughly depressed sifting photo australia burn cd nana',
#  'looking forward last day nflredzone tomorrow',
#  'year took lynx box set granted year get one',
#  'mpsnutrition welcome mpsvt delighted grateful mpsvt relationship',
#  'game el paso look like high school game',
#  'thank god grace',
#  'gutting seeing everyone snapchats getting stuck work christmas new year',
#  'raining hear thunder growl somewhere good day read',
#  'go harder everyone else enough relentless cleaner',
#  'executivegoth tried free alpha trial watch dread sold worth subscription alone incredible',
#  'went earlier today feel like buying anything',
#  'might problem someone close',
#  'ur father ur brother lost transport card pic twitter com zvfzbigivo',
#  'person may report multiple physical symptom fatigue headache digestive problem',
#  'kawells oh art wonderful',
#  'whatever life give even hurt strong act way always strong wall shake never collapse',
#  'super kind never forget total lifechanger best year since teen blessed',
#  'happy worldfringeday think appropriate year perform edfringe first time cultureclashuk',
#  'head anointed cup runneth pour empty cup delight love joy',
#  'last day cheating diet exercise routine tomorrow',
#  'addressing loneliness danger must watch indulging sexy new robotic industry provide lonely robot companion pic twitter com qafhghhnj',
#  'people truly amazing inspiring day',
#  'nobody know birthday depressed',
#  'depression like want anything want something want time',
#  'mah laconic style vape kit pic twitter com wdcjrenfhw',
#  'love u u expect someone love u',
#  'blackvoices keep gucci sober clear minded see europe tour killing game right',
#  'hate u give show hopelessness maverick thrown onto road police without reason searched multiple time kid watch police abuse power',
#  'able treat queen thing want pleasing feeling',
#  'yet marliepacker set back row bar high tackling support play outstanding congrats th cap inspiring',
#  'michelle clearly referring life pay vacation servant beck call',
#  'comforting inspiring faith housefires goodfather thank beautiful song itswhoiam itswhoyouare youtperfectinallofyourways',
#  'finished schitt creek even know',
#  'happy birthday beautiful xan radebe',
#  'simple wallpaper ever',
#  'ntyrbbygrl u make heart flutter',
#  'amberx butcher jim landed arse hilarious ninjawarriorau',
#  'fresh wound best mean relief inner stress',
#  'something epic sense sort desperation desperation feel nothing lose',
#  'even school anatomy still manages ruin day fuck bitch teacher',
#  'year since husband flew nyc christmas',
#  'wish power multiplied insight understanding made clearer joy',
#  'lyttleton love hope reason would despair',
#  'wow page left first full art book amazing',
#  'best anxiety depression quick fix loving eye pup world feel time hopeful receiving pic twitter com plcs kuygj',
#  'dick gregory amp jerry lewis great creativity imagination brought smile amp laughter place always illuminated',
#  'disappointed',
#  'heard insecurity come three type feeling helplessness feeling hopelessness feeling worthlessness',
#  'one best friend got engaged',
#  'normal feel lonely partner want one emotion signal need met something get thinking away making friend',
#  'pic twitter com iaprwpanjk',
#  'man spirit endure sickness crushed spirit bear proverb esv',
#  'getting jd coke',
#  'le week go',
#  'social connection important throughout life pic twitter com tpvun egqv',
#  'laughter instant vacation ntake vacation n vacation laughter happy alenanaron lifecoach positvity',
#  'see tweet one timeline make life lot easier say hello add',
#  'shout fellow step pers got recovery clean',
#  'people may preoccupied thought worthlessness inappropriate guilt helplessness hopelessness self hatred',
#  'lifewithselg despacito u came life nur aroma flared life nur almond eye make pulse gushing nur smile gleam bright',
#  'depressing true pic twitter com hnil jfkdx',
#  'morrgancatt dont bad smile smile often share smile fan',
#  'indian fan hate joe buck im glad look old af bitter allstargame',
#  'set boundary eventually create unintended stress anxiety setting boundary make life whole lot easier',
#  'vvixie thanks bby tiff got pair probably steal lol',
#  'someone destroyed could done awful thing pic twitter com l ubpqp qk',
#  'nbcnews markhalperin keirsimmons well funny cause know serious russian mafia atty',
#  'bos text work holiday',
#  'dngokingyok hetero guilty pleasure',
#  'great fun fake enjoyment feeling new year eve need talk',
#  'view valid pic twitter com u cjqkmtlx',
#  'promoting taeny tiff yes',
#  'mother used profane term home would sued removed home',
#  'kokobop weird name nbut remember said lit growl exo accepting name',
#  'let panic cause say yes someone everything within saying',
#  'decoration come remains issue regular make huge difference pic twitter com dmfzqqk',
#  'nail polish hardened gummy place bottle pan boiling water polish like new',
#  'best revenge ever success',
#  'omg said kyungsoo looked gloomy instant smile melting',
#  'thank god grace',
#  'pic twitter com ndjfnoqsfp',
#  'like know demon chat time pic twitter com yaduuzhu e',
#  'rfc daryl lw next bet let start going golf get pished day',
#  'possible trying convince huge course right come',
#  'end favourite tv show main character dying',
#  'noahwebhouse review book faulted spending much time webster introductory front matter brilliant',
#  'planned wedding day mother nature go fuck everything thanks bunch',
#  'omg keep getting better muggymike amp sam go back loveisland drama hilarious',
#  'national prevention lifeline offer help talk',
#  'know christmas gift honestly got sister tablet got ring light phone',
#  'see truetwit nwho smiling brightly nwell reckon cool nand reckon rightly',
#  'edge seat gameofthrones loved dragonsonthewall',
#  'president u tweet like regina george',
#  'th step overcoming open mind belief system screwed find another truth',
#  'know like whenever see smile feel happiness around',
#  'hour kip class blessed happy smiling',
#  'minute arrives month begin look others speak problem pic twitter com gdhivi ean',
#  'may cut mexican food',
#  'aw steve story heartbreaking worst feeling world well done great job storyline',
#  'telling eats alive',
#  'mine baby headache love smile frown wrong right pain happiness everything',
#  'look little guy connecting magical self nwhat keep life magical anewperspective magical',
#  'eahelp mcmalveiro hi miguel awesome thank much updating u claire',
#  'going keep banging co true focus get stop telling tell happy strong confident powerful co co brilliant mind listens tell pic twitter com cimonc ocm',
#  'graduated yesterday already family member asking job got nightmare',
#  'never actually watched whole ugly betty watched depressed need ending',
#  'new music friday first single next project untitled mattrod hiphop boston hartford animosity thesemycities',
#  'paracetamol anti pyritique cant anawer correctly due much nerve shame',
#  'anohnitweets completely brilliant performance moving honest',
#  'finished playing mystic messenger didnt expect amount angst n mysticmessenger feel',
#  'rt findrealhealth using manage learn side effect pic twitter com ngjndxhvlm',
#  'hate mail gotta love n hate writerslife justsaying begin start lovemylife positivevibes',
#  'older people contact family friend neighbour le week contact le month pic twitter com ronjvwr',
#  'one day everything end inevitable love god quesarito taco bell',
#  'thank sending random kind people life need smiling grateful',
#  'atrsya truly decide happiness',
#  'horny anyone horny bi sex london snapchat gaysnap hornysnap snapchatgay snapchathorny gaysnapchat hornysnapchat snapgay snap',
#  'chadbowers look forward next year heroesonline con charlotte get darkhawk signed awesomeness',
#  'christmas wonderful time year also horrific time year',
#  'wore black today metaphor state mind also state america day',
#  'longing see face christ jesus rejoice anticipation coming',
#  '',
#  'watching victoria secret fashion show error never want eat',
#  'today selfcare beauty amp laugh kung fu panda wellness joy laughter selfcare therapist philadelphia',
#  'plz hesitate come translation nservices either waiting come',
#  'woke looking poor shattered phone',
#  'walu go thisislukeowen yes especially love ramble chat love go topic like ten minute awesomeness',
#  'actually incredibly happy soul body connected able amazing time living planet grateful',
#  'never experienced pas passing decision people make hopelessness utter desperation trust know hopeless buy',
#  'wow last chick bit intense poor freddie bit unnerved lol ninjawarriorau',
#  'discouraged failure learn thomas j watson motivationalquote success',
#  'pattonoswalt ericaroman amazing folk foaming mouth judge happy pattonoswalt',
#  'watching senator adeleke joyful dance step morning got rolling dude bougie',
#  'anyone tip help worry le hmu',
#  'satisfyingtaste theanimalvines used make peanut butter energy ball time famjam loved recipe yummy',
#  'u feel lonely afraid desperate empty inside suicidal u r alone long ago',
#  'new madden franchise league xb coming soon follow amp dm interested full team league st help decide rule amp roster',
#  'way best friend airport fly back state today',
#  'bravoallstarz look like going amazing season cheer',
#  'wanted become top idol make everyone happy cheer lot',
#  'lexis beautiful make',
#  'tuckercarlson love relentless',
#  'great looked forward every tomorrow anticipation new year',
#  'struggling festive season open offer call pw',
#  'watch eclipse astral valley longest time totality across country thankful',
#  'mattwhite football tweet deadlinedaylive brilliant music make',
#  'ebullient ih bul yunt adj boiling bubbling excitement exuberant boiling liquid called ebullient excited enthusiastic',
#  'going finally start getting ready move',
#  'lost moment without lost world world moment lostinthemoment',
#  'greenarmy thank glad enjoying',
#  'amyandrewsfox good morning amy smile good lion fan',
#  'prisonplanet donaldjtrumpjr read pissed trump bed',
#  'struggle w need u hopeful struggle need find way back',
#  'billjoehughes sound delightful',
#  'perfect together im shy wont reach guess never know could',
#  'joke suffered time year implore look loved one',
#  'coming snap chat add asap mateo bkny snapchat',
#  'working kitchen table whirring next working facebook stuff printer stimpack bliss',
#  'reject turn tv medium emitting psyop sentiment analysis algorithm hopelessness choose',
#  'month hiatus watch movie multiplex ugly maybe better watching',
#  'happens person least two week mood',
#  'get spend new year home alone lonely',
#  'depressed lonely stuck deep never ending hole',
#  'learning pretend good time become natural skill hope one day genuine',
#  'far stop texting said something hopefully show house',
#  'sigh cried much much pain',
#  'thank god last presentation tomorrow last day uni year really need day',
#  'depressed weather depressed depression sicknotweak',
#  'sad day edmonton praying lost life',
#  'losing uncle wedding dunno',
#  'nobody care real life nobody care gonna stop sharing nightmare people worried like actually helping person',
#  'dangerous addicting see peaceful wanna deal',
#  'come see value life feel like born way seeing self value',
#  'sometimes want apology make thing better nothing apologize opposite deserve apology heart smell loneliness desperation',
#  'kicked kerb big company yet quest decent job',
#  'come realization phone going make day',
#  'absolutly shocking service bookingcom especially owed expected better comp ive dealt yr unhappy badservice',
#  'ready take sneaker hurting',
#  'journey become youtuber easy walk purpose fix record edit post see easy one person needed message hater',
#  'want participate anymore',
#  'incredible dr david feifel alive man amazing person pic twitter com uw p yd ez',
#  'honestly trust anyone point',
#  'understand shit fast',
#  'even nobody anyone',
#  'stay bed nothing feeling life today',
#  'yet another sleepless night record comfort stuff watching hairy bikers place sun wee small hour little dog',
#  'moment get blindsided something expecting state total disappointment heartache',
#  'really respect love anybody else',
#  'cry something repeating head cry',
#  'done absolute fuck last day',
#  'suck fall hard someone leave like nothing',
#  'sometimes love painful eats nothing',
#  'anything pic twitter com xvibd hpae',
#  'riding metro feeling palpable morning',
#  'want stay bed day',
#  'feel like shit one vent',
#  'starting feel really anxious sad empty',
#  'im way around feel upset sad',
#  'simple stop texting',
#  'work everyday rest year',
#  'funk day feeling little',
#  'weird get x depressed christmas break every year',
#  'anyway walk around house try look thing try think feel deep pain deep longing see remember germany left',
#  'gonna see one last time',
#  'going like going',
#  'well goodbye gent life',
#  'sick new year resolution get hitch get love happy maybe staying alive',
#  'scare get opened like pooring salt hate feeling pain im',
#  'going say goodbye beloved pup upcoming week',
#  'wide awake thought supposed know as instead mind racing',
#  'moment depression kick even',
#  'would understanding noone noone people life busy schedule nothing time time think used longer think could',
#  'boo would nice nobody love',
#  'used talking nothing hour talking really happened',
#  'want watch one punch man get bed',
#  'tell end night gonna cut arm',
#  'want good day monster keep pushing',
#  'forgot cheese cake work',
#  'ha ha realised never actually therapy still know depressed sad time',
#  'feel like prisoner life like life jail lifetime sentence',
#  'amazonprimeday broke reality another day depressing',
#  'lost mind',
#  'ke na le problem le guy way many u world people find lonely alone',
#  'one thing hate ignored everybody seems ugh',
#  'funny night hate sleeping sleeping help feel dead explanation feeling',
#  'kill easy',
#  'best friend died year ago day car crash year still killing literally torn need help',
#  'sweet nice guy realizing never really deserved story life',
#  'upset',
#  'jfc another bad morning dont even anything depressed oh hang leaving fester poverty line year',
#  'year old woman wth chronic pain noticed breaking cry everyday mood seems positive intense intrusive thought strong micro dos feel like seeing improvement pic twitter com cftdb q ka',
#  'hate hate hate hate hate life hate',
#  'year fuckd wait hated year still depressed hard time getting fuck',
#  'know anymore life parent know still life fact feel shallow life always seem unfair point u feel nothing',
#  'bad dream come true got feeling like crapulet',
#  'suffering serious depression suck plan time everything',
#  'depression suck would never wish anyone suck tired controlling life really',
#  'literally thing reason live really intent tho',
#  'lot people know well',
#  'apart one minute medical appointment seen spoken another person since sunday',
#  'listen someone tell wonderful christmas dinner game etc asked mine',
#  'went church mom huge chunk sermon basically faith weak go church tell mom antidepressant',
#  'let sit wallow self pity',
#  'feeling okish one minute reason ever psychiatrist right chronic depression give warning mood dip feel like top anxiety high',
#  'watching show still keeping depression anxiety bay stress crushing',
#  'guess feeling well feel low throat starting flare cope right',
#  'yeah watch depressing film like cyberbully sad connect',
#  'tripped hard today promising',
#  'dear life please gently',
#  'would feel parent argue every single day',
#  'looking profile half family account twitter extremely depressed life full chronicpain living normal fulfilled life like taking existence',
#  'people exercise feel better full depressed k bike mile shower curl ball weeps',
#  'live normal life friend go fun believe etc stop choice',
#  'say life short bored already',
#  'insecure withhold praise another achievement',
#  'hate seeing shit photo think really look like',
#  'super depressed reason yaayyy screw life lol',
#  'see cry running blade ankle maybe think twice said said',
#  'literally bed day',
#  'felt good least able get laundry started done anything past though least fed today',
#  'feeling everyone giving still fighting argh',
#  'guy nothing live tired living even friend cheer',
#  'worst thing tease thinking getting better drop back bottom harder every time wish could happy pic twitter com zrf h l h',
#  'past day drank bottle beer pint cider half bottle prosecco',
#  'everything nothing',
#  'trouble catching breath',
#  'creep',
#  'hello darkness old friend come talk',
#  'think habit reading morning root cause feeling throughout day specially',
#  'mentally suffered iwanttodie worthless lifewithoutcolor pain suicidal',
#  'really want someone talk late night someone understands',
#  'weighing holiday terrible idea',
#  'scioly rest year',
#  'walk around house sometimes think momentarily back take care realize never back go away trip go away vacation work go store',
#  'made account judged people know cause like would anyone else',
#  'honestly get im last choice everything',
#  'time year usually full excitement',
#  'put heart soul something year get treated like exist',
#  'depressed always smiling right learned go public safe',
#  'determined cut string scissors knife weak break pic twitter com bpkmtyrl',
#  'cramping fucking bad bb boy rub tummy',
#  'shouldnt let bother hate night like thought wont leave peace',
#  'really thinking killing',
#  'feeling little time bed',
#  'day ended poorly ended calling sally royal pain as seem think bad whatever tho',
#  'feel like long since life want',
#  'people constant desire talk leave alone miserable wallow self loathing',
#  'pick piece heart dignity pathetic humiliating',
#  'need get godforsaken place',
#  'broken thousand tiny piece never put back together',
#  'people listen',
#  'sister emotional breakdown aging death something take seriously month ago',
#  'life cruel',
#  'well inviting everyone one coming',
#  'mom said going take hospital started freaking threw living room floor much hospital point going',
#  'today ate month old rancid meat forgot month',
#  'anxiety disorder ptsd depression real today battling happiness fading brain messing badly trying hard cry trying hard stay positive struggling',
#  'feel like lost interest text back cry suck saw story snapchat',
#  'ate bag sweet life',
#  'feel like purpose life',
#  'feel fucking alone tonight even care living right',
#  'little thing affect massively',
#  'tbh excited celebrate christmas disappointment',
#  'day draw near end feel though suffocating losing piece never come',
#  'guess kind person wanna hang',
#  'surprised many struggle much help get take drug work take',
#  'silence might suffocating unbearable deny comfort need',
#  'sinking fast even know start save',
#  'apparently mosquito bit inside thigh think action month',
#  'thought become afraid thing safety routine know',
#  'hate life never going get better depression hell feel one understand understand',
#  'everything coming back sudden good feeling',
#  'know sound like hot mess know related mean',
#  'wish took holiday instead work',
#  'surrounded winter constantly aware',
#  'lil boat middle ocean lost alone always getting battered force beyond control',
#  'lot people looking find',
#  'ever feel like eating drinking anything',
#  ...]

# %%
# Creating the Bag of Words model

from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X = cv.fit_transform(corpus).toarray()
y = df.iloc[:, -1]

# Creating a pickle file for the CountVectorizer
# pickle.dump(cv, open('./data/cv-transform.pkl', 'wb'))

# Model Building
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# Fitting Naive Bayes to the Training set
classifier = MultinomialNB(alpha=0.2)
classifier.fit(X_train, y_train)

# Creating a pickle file for the Multinomial Naive Bayes model
filename = './data/depression2.pkl'
# pickle.dump(classifier, open(filename, 'wb'))

# %%
score = classifier.score(X_test, y_test)
score
# Out:
# 0.7633136094674556

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.66      0.73       166
#            1       0.73      0.86      0.79       172
#
#     accuracy                           0.76       338
#    macro avg       0.77      0.76      0.76       338
# weighted avg       0.77      0.76      0.76       338

# %%
df['target'].value_counts()

# %%
filename = 'depression2.pkl'
classifier1 = pickle.load(open(filename, 'rb'))
cv1 = pickle.load(open('cv-transform.pkl','rb'))

# %%
score2 = classifier1.score(X_test, y_test)
score2

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': SVC(),
        'params' : {
            'C': [0.1, 1, 10, 100, 1000],
            'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
            'kernel': ['rbf', 'linear']
        }  
    },
    'navie_bayes': {
        'model': GaussianNB(),
        'params' : {
            'var_smoothing': np.logspace(0,-9, num=100)
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_

# %%
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score                               best_params
# 0                  svm    0.754443  {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# 1          navie_bayes    0.634988    {'var_smoothing': 0.01873817422860384}
# 2  logistic_regression    0.749233                                  {'C': 5}
